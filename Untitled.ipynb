# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

url = 'https://unstats.un.org/unsd/methodology/m49/'
r = requests.get(url)
html_doc = r.text
soup = BeautifulSoup(html_doc)
soup
# Out:
# <!DOCTYPE html>\n\n<!--[if IE 8]> <html lang="en" class="ie8"> <![endif]-->\n<!--[if IE 9]> <html lang="en" class="ie9"> <![endif]-->\n<!--[if !IE]><!--> <html lang="en"> <!--<![endif]-->\n<head>\n<!-- Title -->\n<title>UNSD \u2014 Methodology </title><!-- Meta -->\n<!-- Meta -->\n<meta charset="unicode-escape"/>\n<meta content="IE=edge" http-equiv="X-UA-Compatible"/>\n<meta content="width=device-width, initial-scale=1.0" name="viewport"/>\n<meta content="United Nations Statistics Divisin - Methodology" name="description"/>\n<meta content="United Nations Statistics Division" name="author"/>\n<!-- Favicon -->\n<link href="/unsd/methodology/assets/img/favicon.ico" rel="shortcut icon"/>\n<!-- Web Fonts -->\n<link href="//fonts.googleapis.com/css?family=Open+Sans:400,300,600&amp;subset=cyrillic,latin" rel="stylesheet" type="text/css"/>\n<!-- CSS Global Compulsory -->\n<link href="/unsd/methodology/assets/plugins/bootstrap/css/bootstrap.min.css" rel="stylesheet"/>\n<link href="/unsd/methodology/assets/css/style.css" rel="stylesheet"/>\n<!-- CSS Header and Footer -->\n<link href="/unsd/methodology/assets/css/headers/header-default.css" rel="stylesheet"/>\n<link href="/unsd/methodology/assets/css/headers/header-v1.css" rel="stylesheet"/>\n<link href="/unsd/methodology/assets/css/footers/footer-default.css" rel="stylesheet"/>\n<!-- CSS Implementing Plugins -->\n<link href="/unsd/methodology/assets/plugins/animate.css" rel="stylesheet"/>\n<link href="/unsd/methodology/assets/plugins/line-icons-pro/styles.css" rel="stylesheet"/>\n<link href="/unsd/methodology/assets/plugins/line-icons/line-icons.css" rel="stylesheet"/>\n<link href="/unsd/methodology/assets/plugins/owl-carousel/owl-carousel/owl.carousel.css" rel="stylesheet"/>\n<link href="/unsd/methodology/assets/plugins/reveal/reveal.css" rel="stylesheet"/> <!-- from http://zurb.com/playground/reveal-modal-plugin -->\n<link href="/unsd/methodology/assets/css/pages/profile.css" rel="stylesheet"/>\n<!-- CSS Customization -->\n<link href="/unsd/methodology/assets/css/theme-colors/blueUN.css" rel="stylesheet"/>\n<link href="/unsd/methodology/assets/css/custom.css" rel="stylesheet"/>\n<link href="/unsd/methodology/assets/css/jquery.treetable.css" rel="stylesheet" type="text/css">\n<link href="/unsd/methodology/assets/css/custom-methods-ccsa.css" rel="stylesheet"/>\n<!-- IE 9 Fallback-->\n<!--[if IE 9]>\r\n        <link href="~/assets/css/ie.css" rel="stylesheet">\r\n      <![endif]-->\n<!-- GOOGLE FONTS -->\n<link href="//fonts.googleapis.com/css?family=Open+Sans:300,400italic,400,600,700" rel="stylesheet" type="text/css"/>\n<link href="//fonts.googleapis.com/css?family=Roboto+Condensed:300,300italic,400italic,700,400,300" rel="stylesheet" type="text/css"/>\n<link href="//maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css" rel="stylesheet"/>\n<script src="/unsd/methodology/assets/plugins/jquery/jquery.min.js" type="text/javascript"></script>\n<script src="/unsd/methodology/assets/plugins/reveal/jquery.reveal.js" type="text/javascript"></script>\n<script src="/unsd/methodology/assets/js/custom.js" type="text/javascript"></script>\n</link></head>\n<body class="layout">\n<!-- WRAPPER -->\n<div class="wrapper">\n<!--=== Page Header === -->\n<div class="header header-v1">\n<!-- Topbar-v1 -->\n<div class="topbar-v1 margin-bottom-20 hidden-xs">\n<div class="container">\n<div class="row">\n<div class="col-sm-8">\n<div class="topbar">\n<ul class="list-unstyled top-v1-contacts">\n<!--<li>\r\n              <a href="~/">UN-GGIM Home</a>\r\n            </li>\r\n\r\n            <li><i class="fa fa-angle-double-right"></i>\r\n            </li> -->\n<li>\n<a href="http://www.un.org/">United Nations</a>\n</li>\n<li><i class="fa fa-angle-double-right"></i>\n</li>\n<li>\n<a href="http://www.un.org/desa">Department of Economic and Social Affairs</a>\n</li>\n<li><i class="fa fa-angle-double-right"></i>\n</li>\n<li>\n<a href="http://unstats.un.org/unsd/">Statistics Division</a>\n</li>\n</ul>\n</ ...

# %%
data = []
table = soup.find('table', attrs={'class': 'table table-striped'})

header_cols = table.find_all('th')
header_cols = [(ele.text.strip()).encode('utf-8') for ele in header_cols]
data.append([ele for ele in header_cols if ele])

rows = table.find_all('tr')
for row in rows:
    cols = row.find_all('td')
    cols = [(ele.text.strip()).encode('utf-8') for ele in cols]
    
    data.append([ele for ele in cols if ele])

# Have to drop the 2nd element because it comes up blank in this table's loop
del data[1]

# Extract the headers
headers = data.pop(0)

df = pd.DataFrame(data, columns=headers)

df
# Out:
#                                        Country or Area M49 code  \
# 0                                          Afghanistan      004
# 1                                        Åland Islands      248
# 2                                              Albania      008
# 3                                              Algeria      012
# 4                                       American Samoa      016
# 5                                              Andorra      020
# 6                                               Angola      024
# 7                                             Anguilla      660
# 8                                           Antarctica      010
# 9                                  Antigua and Barbuda      028
# 10                                           Argentina      032
# 11                                             Armenia      051
# 12                                               Aruba      533
# 13                                           Australia      036
# 14                                             Austria      040
# 15                                          Azerbaijan      031
# 16                                             Bahamas      044
# 17                                             Bahrain      048
# 18                                          Bangladesh      050
# 19                                            Barbados      052
# 20                                             Belarus      112
# 21                                             Belgium      056
# 22                                              Belize      084
# 23                                               Benin      204
# 24                                             Bermuda      060
# 25                                              Bhutan      064
# 26                    Bolivia (Plurinational State of)      068
# 27                    Bonaire, Sint Eustatius and Saba      535
# 28                              Bosnia and Herzegovina      070
# 29                                            Botswana      072
# ..                                                 ...      ...
# 219                                         Tajikistan      762
# 220                                           Thailand      764
# 221                                        Timor-Leste      626
# 222                                               Togo      768
# 223                                            Tokelau      772
# 224                                              Tonga      776
# 225                                Trinidad and Tobago      780
# 226                                            Tunisia      788
# 227                                             Turkey      792
# 228                                       Turkmenistan      795
# 229                           Turks and Caicos Islands      796
# 230                                             Tuvalu      798
# 231                                             Uganda      800
# 232                                            Ukraine      804
# 233                               United Arab Emirates      784
# 234  United Kingdom of Great Britain and Northern I...      826
# 235                        United Republic of Tanzania      834
# 236               United States Minor Outlying Islands      581
# 237                           United States of America      840
# 238                       United States Virgin Islands      850
# 239                                            Uruguay      858
# 240                                         Uzbekistan      860
# 241                                            Vanuatu      548
# 242                 Venezuela (Bolivarian Republic of)      862
# 243                                           Viet Nam      704
# 244                          Wallis and Futuna Islands      876
# 245                                     Western Sahara      732
# 246                                              Yemen      887
# 247                                             Zambia      894
# 248                                           Zimbabwe      716
#
#     ISO-alpha3 code
# 0               AFG
# 1               ALA
# 2               ALB
# 3               DZA
# 4               ASM
# 5               AND
# 6               AGO
# 7               AIA
# 8               ATA
# 9               ATG
# 10              ARG
# 11              ARM
# 12              ABW
# 13              AUS
# 14              AUT
# 15              AZE
# 16              BHS
# 17              BHR
# 18              BGD
# 19              BRB
# 20              BLR
# 21              BEL
# 22              BLZ
# 23              BEN
# 24              BMU
# 25              BTN
# 26              BOL
# 27              BES
# 28              BIH
# 29              BWA
# ..              ...
# 219             TJK
# 220             THA
# 221             TLS
# 222             TGO
# 223             TKL
# 224             TON
# 225             TTO
# 226             TUN
# 227             TUR
# 228             TKM
# 229             TCA
# 230             TUV
# 231             UGA
# 232             UKR
# 233             ARE
# 234             GBR
# 235             TZA
# 236             UMI
# 237             USA
# 238             VIR
# 239             URY
# 240             UZB
# 241             VUT
# 242             VEN
# 243             VNM
# 244             WLF
# 245             ESH
# 246             YEM
# 247             ZMB
# 248             ZWE
#
# [249 rows x 3 columns]

# %%
df.columns
# Out:
# Index([u'Country or Area', u'M49 code', u'ISO-alpha3 code'], dtype='object')

# %%
df.drop([u'M49 code'], axis=1)
# Out:
#                                        Country or Area ISO-alpha3 code
# 0                                          Afghanistan             AFG
# 1                                        Åland Islands             ALA
# 2                                              Albania             ALB
# 3                                              Algeria             DZA
# 4                                       American Samoa             ASM
# 5                                              Andorra             AND
# 6                                               Angola             AGO
# 7                                             Anguilla             AIA
# 8                                           Antarctica             ATA
# 9                                  Antigua and Barbuda             ATG
# 10                                           Argentina             ARG
# 11                                             Armenia             ARM
# 12                                               Aruba             ABW
# 13                                           Australia             AUS
# 14                                             Austria             AUT
# 15                                          Azerbaijan             AZE
# 16                                             Bahamas             BHS
# 17                                             Bahrain             BHR
# 18                                          Bangladesh             BGD
# 19                                            Barbados             BRB
# 20                                             Belarus             BLR
# 21                                             Belgium             BEL
# 22                                              Belize             BLZ
# 23                                               Benin             BEN
# 24                                             Bermuda             BMU
# 25                                              Bhutan             BTN
# 26                    Bolivia (Plurinational State of)             BOL
# 27                    Bonaire, Sint Eustatius and Saba             BES
# 28                              Bosnia and Herzegovina             BIH
# 29                                            Botswana             BWA
# ..                                                 ...             ...
# 219                                         Tajikistan             TJK
# 220                                           Thailand             THA
# 221                                        Timor-Leste             TLS
# 222                                               Togo             TGO
# 223                                            Tokelau             TKL
# 224                                              Tonga             TON
# 225                                Trinidad and Tobago             TTO
# 226                                            Tunisia             TUN
# 227                                             Turkey             TUR
# 228                                       Turkmenistan             TKM
# 229                           Turks and Caicos Islands             TCA
# 230                                             Tuvalu             TUV
# 231                                             Uganda             UGA
# 232                                            Ukraine             UKR
# 233                               United Arab Emirates             ARE
# 234  United Kingdom of Great Britain and Northern I...             GBR
# 235                        United Republic of Tanzania             TZA
# 236               United States Minor Outlying Islands             UMI
# 237                           United States of America             USA
# 238                       United States Virgin Islands             VIR
# 239                                            Uruguay             URY
# 240                                         Uzbekistan             UZB
# 241                                            Vanuatu             VUT
# 242                 Venezuela (Bolivarian Republic of)             VEN
# 243                                           Viet Nam             VNM
# 244                          Wallis and Futuna Islands             WLF
# 245                                     Western Sahara             ESH
# 246                                              Yemen             YEM
# 247                                             Zambia             ZMB
# 248                                           Zimbabwe             ZWE
#
# [249 rows x 2 columns]

# %%
df.to_csv('./data_sets/country_codes.csv')
