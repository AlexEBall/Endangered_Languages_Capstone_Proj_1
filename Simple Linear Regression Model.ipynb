# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression

sns.set()
# %matplotlib inline

endangered_languages = pd.read_csv('./data_sets/endangered_languages_ML.csv', index_col=0)
endangered_languages.head()
# Out:
#                    Speakers  Fertility Rate Avg  2018 Rank  2018 Score  \
# Language
# South Italian     7500000.0            1.714074       35.0       55.77
# Sicilian          5000000.0            1.714074       35.0       55.77
# Lombard           3500000.0            1.714074       35.0       55.77
# Emilian-Romagnol  2000000.0            1.714074       35.0       55.77
# Piedmontese       2000000.0            1.714074       35.0       55.77
#
#                   Number of Countries Spoken  GDP Average (Current US $)  \
# Language
# South Italian                              1                944337429320
# Sicilian                                   1                944337429320
# Lombard                                    2                944337429320
# Emilian-Romagnol                           2                944337429320
# Piedmontese                                1                944337429320
#
#                   The former Yugoslav Republic of Macedonia  Ethiopia  \
# Language
# South Italian                                             0         0
# Sicilian                                                  0         0
# Lombard                                                   0         0
# Emilian-Romagnol                                          0         0
# Piedmontese                                               0         0
#
#                   Costa Rica  Sudan  ...  Venezuela (Bolivarian Republic of)  \
# Language                             ...
# South Italian              0      0  ...                                   0
# Sicilian                   0      0  ...                                   0
# Lombard                    0      0  ...                                   0
# Emilian-Romagnol           0      0  ...                                   0
# Piedmontese                0      0  ...                                   0
#
#                   Sri Lanka  Argentina  Uzbekistan  Senegal  \
# Language
# South Italian             0          0           0        0
# Sicilian                  0          0           0        0
# Lombard                   0          0           0        0
# Emilian-Romagnol          0          0           0        0
# Piedmontese               0          0           0        0
#
#                   Critically endangered  Definitely endangered  Extinct  \
# Language
# South Italian                         0                      0        0
# Sicilian                              0                      0        0
# Lombard                               0                      1        0
# Emilian-Romagnol                      0                      1        0
# Piedmontese                           0                      1        0
#
#                   Severely endangered  Vulnerable
# Language
# South Italian                       0           1
# Sicilian                            0           1
# Lombard                             0           0
# Emilian-Romagnol                    0           0
# Piedmontese                         0           0
#
# [5 rows x 161 columns]
