# %%
import pandas as pd

endangered_languages = pd.read_csv('./data_sets/endangered_languages_potential_final.csv', index_col=0)

# %%
endangered_languages.describe()
# Out:
#            Speakers     Latitude    Longitude  Fertility Rate Avg  \
# count  2.514000e+03  2694.000000  2694.000000         2697.000000
# mean   5.413061e+04    16.429177    22.710094            3.887735
# std    3.129682e+05    23.209939    92.390007            1.417819
# min    0.000000e+00   -55.002800  -174.197800            1.601111
# 25%    5.000000e+01    -2.638475   -69.169900            2.203556
# 50%    7.970000e+02    16.133300    31.055750            3.910852
# 75%    6.895500e+03    34.380350   102.452925            4.996685
# max    7.500000e+06    77.481500   177.363200            7.585222
#
#          2018 Rank   2018 Score
# count  1441.000000  1441.000000
# mean     48.267176    52.208557
# std      16.992975     4.542627
# min       1.000000    39.640000
# 25%      34.000000    49.760000
# 50%      51.000000    51.580000
# 75%      57.000000    55.770000
# max      88.000000    70.720000

# %%
endangered_languages.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2697 entries, South Italian to Scanian
# Data columns (total 10 columns):
# Countries Where Spoken    2697 non-null object
# Country Code              2697 non-null object
# Degree of Endangerment    2697 non-null object
# Speakers                  2514 non-null float64
# Latitude                  2694 non-null float64
# Longitude                 2694 non-null float64
# Fertility Rate Avg        2697 non-null float64
# 2018 Rank                 1441 non-null float64
# 2018 Score                1441 non-null float64
# 2018 Band                 1441 non-null object
# dtypes: float64(6), object(4)
# memory usage: 231.8+ KB

# %%
endangered_languages.count()
# Out:
# Countries Where Spoken    2697
# Country Code              2697
# Degree of Endangerment    2697
# Speakers                  2514
# Latitude                  2694
# Longitude                 2694
# Fertility Rate Avg        2697
# 2018 Rank                 1441
# 2018 Score                1441
# 2018 Band                 1441
# dtype: int64

# %%
missing_speakers = endangered_languages['Speakers'].isnull()

# %%
endangered_languages.loc[missing_speakers]
# Out:
#                                                            Countries Where Spoken  \
# Language
# Alemannic                       Germany, Austria, France, Italy, Liechtenstein...
# Bavarian                        Germany, Austria, Hungary, Italy, Switzerland,...
# East Franconian                                           Germany, Czech Republic
# Rhenish Franconian                                                Germany, France
# South Jutish                                                     Germany, Denmark
# Yiddish (Europe)                Germany, Austria, Belarus, Belgium, Denmark, E...
# Judezmo (Europe)                Albania, Algeria, Bosnia and Herzegovina, Bulg...
# Juhur (Israel)                                                             Israel
# Tunisian Judeo-Arabic (Israel)                                             Israel
# A'tong                                                                      India
# ...

# %%
# make sure to include NZL and IRL to this list

eng_speakers = endangered_languages[endangered_languages['Country Code'].isin(['GBR', 'USA', 'CAN', 'AUS', 'NZL', 'IRL'])]

# %%
eng_speakers = eng_speakers.fillna(
    {'2018 Rank': 0.0, '2018 Score': 100.0, '2018 Band': 'Native Speakers'})

# %%
endangered_languages.update(eng_speakers)

# %%
missing_rank = endangered_languages['2018 Rank'].isnull()
missing_rank_countries = endangered_languages[missing_rank].groupby('Country Code')

# %%
endangered_languages[missing_rank]['Country Code'].unique()
# Out:
# array(['BRB', 'ISR', 'BOL', 'NER', 'RUS', 'NPL', 'MLI', 'IRN', 'ARM',
#        'BTN', 'MDA', 'LVA', 'KEN', 'TJK', 'SDN', 'LAO', 'YEM', 'GUM',
#        'VNM', 'SYR', 'EST', 'GRL', 'TZA', 'LSO', 'GUY', 'GNB', 'BWA',
#        'UGA', 'PYF', 'BLZ', 'GIN', 'GHA', 'VEN', 'PNG', 'TCD', 'PRY',
#        'BFA', 'CAF', 'FSM', 'NAM', 'CMR', 'COG', 'MRT', 'GAB', 'ERI',
#        'FJI', 'TLS', 'BEN', 'CIV', 'SUR', 'CYP', 'SLB', 'NCL', 'VUT',
#        'PLW', 'MNG', 'SLE', 'DMA', 'KOR'], dtype=object)

# %%
# Should update Belarus country code to BLR
endangered_languages.loc['Belarusian', 'Country Code'] = 'BLR'
endangered_languages.loc['Polesian', 'Country Code'] = 'BLR'
# Russia has EF score
# South Korea has EF score
# Belarus, Iran, Vietnam, Syria
# Bolivia, Venezuela, Dominican (DMA) --> These need to be updated

russia = endangered_languages[endangered_languages['Country Code'] == 'RUS']
korea = endangered_languages[endangered_languages['Country Code'] == 'KOR']
belarus = endangered_languages[endangered_languages['Country Code'] == 'BLR']
iran = endangered_languages[endangered_languages['Country Code'] == 'IRN']
vietnam = endangered_languages[endangered_languages['Country Code'] == 'VNM']
syria = endangered_languages[endangered_languages['Country Code'] == 'SYR']
bolivia = endangered_languages[endangered_languages['Country Code'] == 'BOL']
venezuela = endangered_languages[endangered_languages['Country Code'] == 'VEN']
dominicana = endangered_languages[endangered_languages['Country Code'] == 'DMA']

# %%
russia = russia.fillna({'2018 Rank': 42.0, '2018 Score': 52.96, '2018 Band': 'Moderate Proficiency'})
korea = korea.fillna({'2018 Rank': 31.0, '2018 Score': 56.27, '2018 Band': 'Moderate Proficiency'})
belarus = belarus.fillna({'2018 Rank': 38.0, '2018 Score': 53.53, '2018 Band': 'Moderate Proficiency'})
iran = iran.fillna({'2018 Rank': 66.0, '2018 Score': 48.29, '2018 Band': 'Very Low Proficiency'})
vietnam = vietnam.fillna({'2018 Rank': 41.0, '2018 Score': 53.12, '2018 Band': 'Moderate Proficiency'})
syria = syria.fillna({'2018 Rank': 76.0, '2018 Score': 46.37, '2018 Band': 'Very Low Proficiency'})
bolivia = bolivia.fillna({'2018 Rank': 61.0, '2018 Score': 48.87, '2018 Band': 'Low Proficiency'})
venezuela = venezuela.fillna({'2018 Rank': 75.0, '2018 Score': 46.61, '2018 Band': 'Very Low Proficiency'})
dominicana = dominicana.fillna({'2018 Rank': 37.0, '2018 Score': 54.97, '2018 Band': 'Moderate Proficiency'})

# %%
endangered_languages.update(russia)
endangered_languages.update(korea)
endangered_languages.update(belarus)
endangered_languages.update(iran)
endangered_languages.update(vietnam)
endangered_languages.update(syria)
endangered_languages.update(bolivia)
endangered_languages.update(venezuela)
endangered_languages.update(dominicana)

# %%
endangered_languages[endangered_languages['Country Code'] == 'RUS'].head()
# Out:
#                     Countries Where Spoken Country Code  \
# Language
# Bashkir                 Russian Federation          RUS
# Chechen                 Russian Federation          RUS
# Chuvash                 Russian Federation          RUS
# Avar                    Russian Federation          RUS
# Kabard-Cherkes  Russian Federation, Turkey          RUS
#
#                Degree of Endangerment   Speakers  Latitude  Longitude  \
# Language
# Bashkir                    Vulnerable  1379727.0   54.7309    55.9863
# Chechen                    Vulnerable  1331844.0   43.1971    45.7031
# Chuvash                    Vulnerable  1325382.0   56.1394    47.2412
# Avar                       Vulnerable   784840.0   42.4801    46.8017
# Kabard-Cherkes             Vulnerable   650000.0   43.7393    43.4289
#
#                 Fertility Rate Avg  2018 Rank  2018 Score  \
# Language
# Bashkir                   1.788074       42.0       52.96
# ...

# %%
endangered_languages['Number of Countries Spoken'] = [
    len(x.split(',')) for x in endangered_languages['Countries Where Spoken']]

# %%
endangered_languages.tail(12)
# Out:
#                    Countries Where Spoken Country Code Degree of Endangerment  \
# Language
# ǁKu ǁ'e                      South Africa          ZAF                Extinct
# ǁKx'au                       South Africa          ZAF                Extinct
# ǁXegwi                       South Africa          ZAF                Extinct
# Karaim (Lithuania)              Lithuania          LTU    Severely endangered
# Bom                          Sierra Leone          SLE    Severely endangered
# Kim                          Sierra Leone          SLE  Critically endangered
# Mo-peng                      Sierra Leone          SLE                Extinct
# Sei                          Sierra Leone          SLE                Extinct
# Island Carib                     Dominica          DMA                Extinct
# Gottscheerish                    Slovenia          SVN  Critically endangered
# Jeju                    Republic of Korea          KOR  Critically endangered
# ...

# %%
endangered_languages[endangered_languages['Country Code'] == 'BRB']
# Out:
# Empty DataFrame
# Columns: [Countries Where Spoken, Country Code, Degree of Endangerment, Speakers, Latitude, Longitude, Fertility Rate Avg, 2018 Rank, 2018 Score, 2018 Band, Number of Countries Spoken]
# Index: []

# %%
endangered_languages[endangered_languages['Country Code'] == 'BLR']
# Out:
#                                        Countries Where Spoken Country Code  \
# Language
# Belarusian  Belarus, Latvia, Lithuania, Poland, Russian Fe...          BLR
# Polesian                             Belarus, Poland, Ukraine          BLR
#
#            Degree of Endangerment   Speakers  Latitude  Longitude  \
# Language
# Belarusian             Vulnerable  4000000.0   53.9560    27.5756
# Polesian               Vulnerable   800000.0   51.8629    23.9501
#
#             Fertility Rate Avg  2018 Rank  2018 Score             2018 Band  \
# Language
# Belarusian              2.3295       38.0       53.53  Moderate Proficiency
# Polesian                2.3295       38.0       53.53  Moderate Proficiency
#
#             Number of Countries Spoken
# Language
# Belarusian                           6
# Polesian                             3

# %%
endangered_languages[missing_speakers].head(20)
# Out:
#                                                            Countries Where Spoken  \
# Language
# Alemannic                       Germany, Austria, France, Italy, Liechtenstein...
# Bavarian                        Germany, Austria, Hungary, Italy, Switzerland,...
# East Franconian                                           Germany, Czech Republic
# Rhenish Franconian                                                Germany, France
# South Jutish                                                     Germany, Denmark
# Yiddish (Europe)                Germany, Austria, Belarus, Belgium, Denmark, E...
# Judezmo (Europe)                Albania, Algeria, Bosnia and Herzegovina, Bulg...
# Juhur (Israel)                                                             Israel
# Tunisian Judeo-Arabic (Israel)                                             Israel
# A'tong                                                                      India
# ...

# %%
# This should be moved below to make sure all countries are added
# Modifiying '2018 Score with native speaking countries tied at rank 1, every other country bumped up
endangered_languages['2018 Rank'] = [x + 1 for x in endangered_languages['2018 Rank']]

# %%
endangered_languages.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2697 entries, South Italian to Scanian
# Data columns (total 11 columns):
# Countries Where Spoken        2697 non-null object
# Country Code                  2697 non-null object
# Degree of Endangerment        2697 non-null object
# Speakers                      2514 non-null float64
# Latitude                      2694 non-null float64
# Longitude                     2694 non-null float64
# Fertility Rate Avg            2697 non-null float64
# 2018 Rank                     2097 non-null float64
# 2018 Score                    2097 non-null float64
# 2018 Band                     2097 non-null object
# Number of Countries Spoken    2697 non-null int64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 332.8+ KB

# %%
endangered_languages[endangered_languages['Country Code'] == 'USA'].head()
# Out:
#                     Countries Where Spoken Country Code  \
# Language
# Yuki              United States of America          USA
# Navajo            United States of America          USA
# Sioux             United States of America          USA
# O'odham (Akimel)  United States of America          USA
# O'odham (Tohono)  United States of America          USA
#
#                  Degree of Endangerment  Speakers  Latitude  Longitude  \
# Language
# Yuki                            Extinct       0.0   37.4336  -118.5908
# Navajo                       Vulnerable  120000.0   35.8044  -108.4750
# Sioux                        Vulnerable   25000.0   43.0588  -102.5244
# O'odham (Akimel)  Definitely endangered   15000.0   33.0590  -112.0479
# O'odham (Tohono)  Definitely endangered   15000.0   31.9186  -111.8798
#
#                   Fertility Rate Avg  2018 Rank  2018 Score        2018 Band  \
# Language
# Yuki                        2.158602        1.0       100.0  Native Speakers
# ...
