# %%
import pandas as pd

data = pd.ExcelFile('./data_sets/Endangered_Languages.xlsx')
endangered_languages = data.parse('Extended_Dataset')
necessary_data = ['Name in English', 'Countries', 'Country codes alpha 3', 'Degree of endangerment',
                  'Number of speakers', 'Latitude', 'Longitude']
endangered_languages = endangered_languages[necessary_data]

""" 
    The column 'Country codes alpha 3' are string values separated by commas. 
    I want to access just the main country that langague is spoken, so converting the string into
    a list and then returning just the first country
"""
endangered_languages['Country codes alpha 3'] = endangered_languages['Country codes alpha 3'].fillna("None")
endangered_languages['Country codes alpha 3'] = [x.split(',')[0] for x in endangered_languages['Country codes alpha 3']]


""" Locating the one row in 'Country codes alpha 3' that has no country code """
noneLook = endangered_languages['Country codes alpha 3'] == "None"

""" 
    After some research using the coordinates, was able to identify the country. 
    https://en.wikipedia.org/wiki/Shinasha_language 
    Adding that information to the 'Country codes alpha 3' and 'Countries' columns
"""
endangered_languages.iloc[405, 1] = 'Ethiopia'
endangered_languages.iloc[405, 2] = 'ETH'

endangered_languages.iloc[405, :]
# Out:
# Name in English                            Boro
# Countries                              Ethiopia
# Country codes alpha 3                       ETH
# Degree of endangerment    Definitely endangered
# Number of speakers                        19878
# Latitude                                10.3581
# Longitude                               35.0024
# Name: 405, dtype: object

# %%
endangered_languages.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2722 entries, 0 to 2721
# Data columns (total 7 columns):
# Name in English           2722 non-null object
# Countries                 2722 non-null object
# Country codes alpha 3     2722 non-null object
# Degree of endangerment    2722 non-null object
# Number of speakers        2539 non-null float64
# Latitude                  2719 non-null float64
# Longitude                 2719 non-null float64
# dtypes: float64(3), object(4)
# memory usage: 148.9+ KB

# %%
endangered_languages['Degree of endangerment'] = endangered_languages['Degree of endangerment'].astype('category')

# %%
endangered_languages.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2722 entries, 0 to 2721
# Data columns (total 7 columns):
# Name in English           2722 non-null object
# Countries                 2722 non-null object
# Country codes alpha 3     2722 non-null object
# Degree of endangerment    2722 non-null category
# Number of speakers        2539 non-null float64
# Latitude                  2719 non-null float64
# Longitude                 2719 non-null float64
# dtypes: category(1), float64(3), object(3)
# memory usage: 130.5+ KB

# %%
missing_speakers = endangered_languages['Number of speakers'].isnull()
endangered_languages[missing_speakers]
# Out:
#                                  Name in English  \
# 2539                                      A'tong
# 2540                                        Aché
# 2541                                        Akie
# 2542                                     Akuriyo
# 2543                                   Alemannic
# 2544                                       Amami
# 2545                                        Amok
# 2546                                       Angku
# 2547                                   Auvergnat
# 2548                                       Balti
# 2549                                Baraba Tatar
# 2550                            Baré (Venezuela)
# 2551                                    Bavarian
# 2552                          Bay Islands Creole
# 2553                                     Bellari
# 2554                        Berbice Dutch Creole
# 2555                                     Bhalesi
# 2556                                        Brao
# 2557                                      Bungee
# 2558                                  Burgundian
# 2559                                    Cabiyarí
# 2560                  Cappadocian Greek (Greece)
# 2561                                    Carabayo
# 2562                                    Cavineña
# 2563                             Cayuga (Canada)
# 2564                        Central Asian Arabic
# 2565                                  Champenois
# 2566                                   Chichimec
# 2567                              Chinook Jargon
# 2568                                     Chiwere
# ...                                          ...
# 2692                                    Tasnusit
# 2693                                         Tat
# 2694                                        Tati
# 2695                                      Tatuyo
# 2696                                        Tazy
# 2697                                     Tempuan
# 2698                                 Toba-Maskoy
# 2699                                      Tolcha
# 2700                         Touggourt Tamazight
# 2701                           Tucano (Colombia)
# 2702              Tunisian Judeo-Arabic (Israel)
# 2703                          Tuscarora (Canada)
# 2704                           Tuyuca (Colombia)
# 2705                               Udi (Georgia)
# 2706                                       Unami
# 2707                       Upper Tanana (Canada)
# 2708                                        Urum
# 2709                                          Wa
# 2710                 Wanano / Kotiria (Colombia)
# 2711                    Western Abenaki (Canada)
# 2712  Western Abenaki (United States of America)
# 2713                                       Wichi
# 2714                                     Yaeyama
# 2715                                  Yazva Komi
# 2716                            Yiddish (Europe)
# 2717                                    Yonaguni
# 2718                                      Yucuna
# 2719                           Yurutí (Colombia)
# 2720                                   Zangskari
# 2721                                     Zidgali
#
#                                               Countries Country codes alpha 3  \
# 2539                                              India                   IND
# 2540                                           Paraguay                   PRY
# 2541                        United Republic of Tanzania                   TZA
# 2542                                           Suriname                   SUR
# 2543  Germany, Austria, France, Italy, Liechtenstein...                   DEU
# 2544                                              Japan                   JPN
# 2545  China, Lao People's Democratic Republic, Myanm...                   CHN
# 2546                                            Myanmar                   MMR
# 2547                                             France                   FRA
# 2548                                    India, Pakistan                   IND
# 2549                                 Russian Federation                   RUS
# 2550                 Venezuela (Bolivarian Republic of)                   VEN
# 2551  Germany, Austria, Hungary, Italy, Switzerland,...                   DEU
# 2552                                           Honduras                   HND
# 2553                                              India                   IND
# 2554                                             Guyana                   GUY
# 2555                                              India                   IND
# 2556  Cambodia, Lao People's Democratic Republic, Vi...                   KHM
# 2557                                             Canada                   CAN
# 2558                                             France                   FRA
# 2559                                           Colombia                   COL
# 2560                                             Greece                   GRC
# 2561                                           Colombia                   COL
# 2562                   Bolivia (Plurinational State of)                   BOL
# 2563                                             Canada                   CAN
# 2564                Uzbekistan, Tajikistan, Afghanistan                   UZB
# 2565                                    Belgium, France                   BEL
# 2566                                             Mexico                   MEX
# 2567                           United States of America                   USA
# 2568                           United States of America                   USA
# ...                                                 ...                   ...
# 2692                                            Algeria                   DZA
# 2693                                         Azerbaijan                   AZE
# 2694                         Iran (Islamic Republic of)                   IRN
# 2695                                           Colombia                   COL
# 2696                                 Russian Federation                   RUS
# 2697                                           Cambodia                   KHM
# 2698                                           Paraguay                   PRY
# 2699                                              India                   IND
# 2700                                            Algeria                   DZA
# 2701                                           Colombia                   COL
# 2702                                             Israel                   ISR
# 2703                                             Canada                   CAN
# 2704                                           Colombia                   COL
# 2705                                            Georgia                   GEO
# 2706                           United States of America                   USA
# 2707                                             Canada                   CAN
# 2708               Georgia, Russian Federation, Ukraine                   GEO
# 2709                                            Myanmar                   MMR
# 2710                                           Colombia                   COL
# 2711                                             Canada                   CAN
# 2712                           United States of America                   USA
# 2713        Argentina, Bolivia (Plurinational State of)                   ARG
# 2714                                              Japan                   JPN
# 2715                                 Russian Federation                   RUS
# 2716  Germany, Austria, Belarus, Belgium, Denmark, E...                   DEU
# 2717                                              Japan                   JPN
# 2718                                           Colombia                   COL
# 2719                                           Colombia                   COL
# 2720                                    India, Pakistan                   IND
# 2721                                               Oman                   OMN
#
#      Degree of endangerment  Number of speakers  Latitude  Longitude
# 2539    Severely endangered                 NaN   25.2844    91.1755
# 2540  Definitely endangered                 NaN  -25.6613   -55.6787
# 2541  Critically endangered                 NaN   -4.7735    37.3315
# 2542  Critically endangered                 NaN    2.8442   -55.7556
# 2543             Vulnerable                 NaN   47.2792     7.6904
# 2544  Definitely endangered                 NaN   28.3672   129.4958
# 2545  Critically endangered                 NaN   21.3610   100.6457
# 2546  Critically endangered                 NaN   21.4888   100.8325
# 2547    Severely endangered                 NaN   45.1278     3.1311
# 2548             Vulnerable                 NaN   35.0659    76.1901
# 2549    Severely endangered                 NaN   55.2478    77.8930
# 2550  Critically endangered                 NaN    1.4280   -66.9287
# 2551             Vulnerable                 NaN   48.4146    12.6123
# 2552  Critically endangered                 NaN   16.3297   -86.5299
# 2553  Critically endangered                 NaN   11.6952    76.4648
# 2554  Critically endangered                 NaN    5.3918   -57.7770
# 2555  Definitely endangered                 NaN   33.3947    76.1352
# 2556    Severely endangered                 NaN   14.1177   106.7644
# 2557  Critically endangered                 NaN   50.0667   -96.9763
# 2558    Severely endangered                 NaN   47.2344     4.2517
# 2559  Critically endangered                 NaN    0.1208   -71.1474
# 2560  Critically endangered                 NaN   40.9798    24.1040
# 2561                Extinct                 NaN   -1.6666   -70.3333
# 2562  Definitely endangered                 NaN  -12.3829   -66.7419
# 2563  Critically endangered                 NaN   43.0190   -80.1506
# 2564  Definitely endangered                 NaN   36.9608    66.8133
# 2565    Severely endangered                 NaN   48.6474     4.3725
# 2566             Vulnerable                 NaN   21.2941  -100.5233
# 2567  Critically endangered                 NaN   45.0591  -123.6091
# 2568                Extinct                 NaN   35.9761   -97.3336
# ...                     ...                 ...       ...        ...
# 2692    Severely endangered                 NaN   34.6230    -1.5614
# 2693    Severely endangered                 NaN   41.3438    48.6254
# 2694  Definitely endangered                 NaN   38.2036    48.2519
# 2695  Definitely endangered                 NaN    0.4174   -70.4882
# 2696    Severely endangered                 NaN   43.9236   134.7967
# 2697    Severely endangered                 NaN   13.7238   107.2038
# 2698    Severely endangered                 NaN  -21.5578   -58.0064
# 2699                Extinct                 NaN   29.9333    80.0326
# 2700    Severely endangered                 NaN   33.0777     6.0671
# 2701             Vulnerable                 NaN    0.6921   -69.8291
# 2702    Severely endangered                 NaN   32.0779    34.8019
# 2703  Critically endangered                 NaN   43.0720   -80.0150
# 2704  Definitely endangered                 NaN    0.3515   -70.2026
# 2705    Severely endangered                 NaN   41.8905    45.9130
# 2706                Extinct                 NaN   39.1300   -76.0253
# 2707  Critically endangered                 NaN   62.3824  -140.8984
# 2708  Definitely endangered                 NaN   47.0102    36.7822
# 2709    Severely endangered                 NaN   21.8705    99.6519
# 2710  Definitely endangered                 NaN    1.0106   -69.6423
# 2711  Critically endangered                 NaN   46.0785   -72.8141
# 2712                Extinct                 NaN   43.0046   -72.2460
# 2713             Vulnerable                 NaN  -22.0041   -63.4130
# 2714    Severely endangered                 NaN   24.3420   124.1537
# 2715    Severely endangered                 NaN   60.0348    57.5360
# 2716  Definitely endangered                 NaN   53.3571    25.2465
# 2717    Severely endangered                 NaN   24.4580   122.9802
# 2718  Definitely endangered                 NaN   -1.2633   -70.6640
# 2719  Definitely endangered                 NaN    1.1370   -70.2136
# 2720  Definitely endangered                 NaN   34.0833    76.8500
# 2721  Critically endangered                 NaN   23.4027    58.0957
#
# [183 rows x 7 columns]

# %%
missing_lat = endangered_languages['Latitude'].isnull()
endangered_languages[missing_lat]
# Out:
#         Name in English Countries Country codes alpha 3  \
# 742   Romani (Colombia)  Colombia                   COL
# 2200             Umbrul   Vanuatu                   VUT
# 2335           Dorasque    Panama                   PAN
#
#      Degree of endangerment  Number of speakers  Latitude  Longitude
# 742              Vulnerable              4858.0       NaN        NaN
# 2200  Critically endangered                 5.0       NaN        NaN
# 2335                Extinct                 0.0       NaN        NaN

# %%
col_dict = {'Name in English': 'Language', 'Countries': 'Countries Where Spoken', 'Country codes alpha 3': 'Country Code',
           'Degree of endangerment': 'Degree of Endangerment', 'Number of speakers': 'Speakers', 'Latitude': 'Latitude',
           'Longitude': 'Longitude'}

endangered_languages.columns = [col_dict.get(x, x) for x in endangered_languages.columns]
endangered_languages.head()
# Out:
#         Language                             Countries Where Spoken  \
# 0  South Italian                                              Italy
# 1       Sicilian                                              Italy
# 2      Low Saxon  Germany, Denmark, Netherlands, Poland, Russian...
# 3     Belarusian  Belarus, Latvia, Lithuania, Poland, Russian Fe...
# 4        Lombard                                 Italy, Switzerland
#
#   Country Code Degree of Endangerment   Speakers  Latitude  Longitude
# 0          ITA             Vulnerable  7500000.0   40.9798    15.2490
# 1          ITA             Vulnerable  5000000.0   37.4399    14.5019
# 2          DEU             Vulnerable  4800000.0   53.4029    10.3601
# 3          BRB             Vulnerable  4000000.0   53.9560    27.5756
# 4          ITA  Definitely endangered  3500000.0   45.7215     9.3273

# %%
endangered_languages.to_csv('./data_sets/Endangered_Languages_Clean.csv')
